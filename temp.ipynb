# %%
import d2l.torch as d2l
import torch
from torch import nn
import numpy as np
import scipy.io as sio

# %%
filepath = r"C:\Users\10485\Desktop\大学物理实验\ydata.mat"
filepath
# Out:
# 'C:\\Users\\10485\\Desktop\\大学物理实验\\ydata.mat'

# %%
data = sio.loadmat(filepath)

# %%
y = data['y']
len(y)
# Out:
# 1284240

# %%
import matplotlib.pyplot as plt
# d2l.use_svg_display()

# %%
fig, ax = plt.subplots(figsize = (20,5))
plt.xticks([])
plt.yticks([])
plt.plot(y[1018370:1018370+200000]);

# %%
fig, ax = plt.subplots(figsize = (20,5))
plt.xticks([])
plt.yticks([])
plt.plot(y[1018370:1018370+200000]);
